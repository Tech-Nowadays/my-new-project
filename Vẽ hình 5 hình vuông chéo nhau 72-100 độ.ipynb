# %%
#Vẽ hình 5 hình vuông chéo nhau 72-100 độ
import turtle
t = turtle.Turtle()
t.pensize(2)
t.pencolor("blue")
#Hình vuông 1
t.left(100)
t.forward(50)
t.right(90)
t.forward(100)
t.right(90)
t.forward(100)
t.right(90)
t.forward(100)
t.right(90)
t.forward(50)
#Hình vuông 2
t.left(72)
t.forward(50)
t.right(90)
t.forward(100)
t.right(90)
t.forward(100)
t.right(90)
t.forward(100)
t.right(90)
t.forward(50)
#Hình vuông 3
t.left(72)
t.forward(50)
t.right(90)
t.forward(100)
t.right(90)
t.forward(100)
t.right(90)
t.forward(100)
t.right(90)
t.forward(50)
#Hình vuông 4
t.left(72)
t.forward(50)
t.right(90)
t.forward(100)
t.right(90)
t.forward(100)
t.right(90)
t.forward(100)
t.right(90)
t.forward(50)
#Hình vuông 5
t.left(72)
t.forward(50)
t.right(90)
t.forward(100)
t.right(90)
t.forward(100)
t.right(90)
t.forward(100)
t.right(90)
t.forward(50)
#End
t.dot(10)
t.hideturtle()
turtle.done()
